# %%
import pandas as pd

# %%
df = pd.read_csv("para cotejar_ Temas Geogebra 2023 - Sheet2.csv")

# %%
df.head()
# Out:
#                        NOMBRE                                   TITULO  \
# 0  Alan Jaret Meza Berrelleza         Perimetro de figuras geometricas
# 1                         NaN                    Perimetro Del Circulo
# 2                         NaN                   Area de figuras planas
# 3                         NaN  Area bajo la curva. Introduccion (1de3)
# 4                         NaN      Area bajo la curva Ejemplo 1 (2de3)
#
#         TEMA         SUBTEMA   CONTENIDO         SUBCONTENIDO DURACION  \
# 0  GEOMETRÍA  Figuras planas   Perimetro  Figuras geometricas    12:47
# 1  GEOMETRÍA  Figuras planas   Perimetro              Circulo    13:20
# 2  GEOMETRÍA  Figuras planas        Area       Figuras planas    21:47
# 3    CÁLCULO        Integral  Integrales   Area bajo la curva    15:31
# 4    CÁLCULO        Integral  Integrales   Area bajo la curva    15:15
#
#       PESO ESTADO REGISTRO
# 0  32,7 MB               *
# 1  28,5 MB               *
# ...

# %%
df['NOMBRE'] = df['NOMBRE'].fillna(method='ffill')

# %%
df.head()
# Out:
#                        NOMBRE                                   TITULO  \
# 0  Alan Jaret Meza Berrelleza         Perimetro de figuras geometricas
# 1  Alan Jaret Meza Berrelleza                    Perimetro Del Circulo
# 2  Alan Jaret Meza Berrelleza                   Area de figuras planas
# 3  Alan Jaret Meza Berrelleza  Area bajo la curva. Introduccion (1de3)
# 4  Alan Jaret Meza Berrelleza      Area bajo la curva Ejemplo 1 (2de3)
#
#         TEMA         SUBTEMA   CONTENIDO         SUBCONTENIDO DURACION  \
# 0  GEOMETRÍA  Figuras planas   Perimetro  Figuras geometricas    12:47
# 1  GEOMETRÍA  Figuras planas   Perimetro              Circulo    13:20
# 2  GEOMETRÍA  Figuras planas        Area       Figuras planas    21:47
# 3    CÁLCULO        Integral  Integrales   Area bajo la curva    15:31
# 4    CÁLCULO        Integral  Integrales   Area bajo la curva    15:15
#
#       PESO ESTADO REGISTRO
# 0  32,7 MB               *
# 1  28,5 MB               *
# ...

# %%
df['TITULO'] = df['TITULO'].str.replace('.mp4', '')

# %%
df[ df['NOMBRE'] == 'Yesenia Merecias Sanchez' ].head(3)
# Out:
#                       NOMBRE                       TITULO       TEMA  \
# 92  Yesenia Merecias Sanchez  1-Razones trigonometrica_V2  GEOMETRÍA
# 93  Yesenia Merecias Sanchez     1-Razones trigonometrica  GEOMETRÍA
# 94  Yesenia Merecias Sanchez         1-TIPO DE ÁNGULOS_V2  GEOMETRÍA
#
#          SUBTEMA                  CONTENIDO             SUBCONTENIDO DURACION  \
# 92  Proporciones  Funciones trigonometricas  Razones Trigonometricas    15:43
# 93  Proporciones  Funciones trigonometricas  Razones Trigonometricas    15:43
# 94       Angulos           Tipos de angulos         Tipos de angulos    13:54
#
#         PESO ESTADO REGISTRO
# 92    152 MB             NaN
# 93  149,8 MB             NaN
# 94  135,7 MB             NaN

# %%
df['TITULO'] = df['TITULO'].str.replace('-', ' ')

# %%
df[ df['NOMBRE'] == 'Yesenia Merecias Sanchez' ].head(3)
# Out:
#                       NOMBRE                       TITULO       TEMA  \
# 92  Yesenia Merecias Sanchez  1 Razones trigonometrica_V2  GEOMETRÍA
# 93  Yesenia Merecias Sanchez     1 Razones trigonometrica  GEOMETRÍA
# 94  Yesenia Merecias Sanchez         1 TIPO DE ÁNGULOS_V2  GEOMETRÍA
#
#          SUBTEMA                  CONTENIDO             SUBCONTENIDO DURACION  \
# 92  Proporciones  Funciones trigonometricas  Razones Trigonometricas    15:43
# 93  Proporciones  Funciones trigonometricas  Razones Trigonometricas    15:43
# 94       Angulos           Tipos de angulos         Tipos de angulos    13:54
#
#         PESO ESTADO REGISTRO
# 92    152 MB             NaN
# 93  149,8 MB             NaN
# 94  135,7 MB             NaN

# %% [markdown]
# <h2>leemos los ya subidos a yt</h2>

# %% [markdown]
# ponemos comas en lugar de salto de linea

# %%
'''
# Lee el contenido del archivo
with open('videos_listos_yt.txt', 'r') as file:
    contenido = file.read()

# Reemplaza los saltos de línea con coma + salto de línea
contenido_modificado = contenido.replace('\n', ',\n')

# Escribe el contenido modificado de vuelta al archivo
with open('tu_archivo_modificado.txt', 'w') as file:
    file.write(contenido_modificado)
'''
    
    
    # Lee el contenido del archivo
with open('videos_listos_yt.txt', 'r', encoding='utf-8') as file:
    contenido = file.read()

# Reemplaza los saltos de línea con coma + salto de línea
contenido_modificado = contenido.replace('\n', ',\n')

# Escribe el contenido modificado de vuelta al archivo
with open('tu_archivo_modificado.txt', 'w') as file:
    file.write(contenido_modificado)
